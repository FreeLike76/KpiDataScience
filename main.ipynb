# %% [markdown]
# # Data Science
# - Sturdent: Dmytro Geleshko
# - Group: IP-91
# - Var: 6
#
# ## Task:
# - Error: exp, normal;
# - Procces linear, quadratic.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Configs

# %%
np.random.seed(6)
plt.rcParams["figure.figsize"] = (20, 6)

SELECTION_SIZE = 1000

# %% [markdown]
# ## Errors

# %% [markdown]
# ### Normal Error

# %%
normal_mean = 2
normal_median = normal_mean
normal_std = 1

normal_error = np.random.normal(normal_mean, normal_std, SELECTION_SIZE)

print("Expected mean:", normal_mean)
print("Expected median:", normal_median)
print("Expected std:", normal_std)
print("\n")
print("Real mean:", np.mean(normal_error))
print("Real median:", np.median(normal_error))
print("Real std:", np.std(normal_error))
print("\n")
print(normal_error[:25])
# Out:
# Expected mean: 2
# Expected median: 2
# Expected std: 1
#
#
# Real mean: 1.991143350566605
# Real median: 1.9785271408784673
# Real std: 0.9646502152637405
#
#
# [ 1.68821633  2.72900392  2.21782079  1.1009082  -0.48678065  2.91325152
#   3.12706373  0.48590677  3.63929108  1.5701064   4.63128056  2.60182225
#   1.66411839  3.23773784  2.11112817  2.12915125  2.07612761  1.84487184
#   2.63422534  2.810655    2.35480861  3.81259031  0.6435242   1.53636803
#   2.82465384]

# %% [markdown]
# ### Normal Error Plot

# %%
plt.hist(normal_error, bins=20, alpha=0.5, label="normal_error")
plt.show()

# %% [markdown]
# ### Exponential Error

# %%
exp_lambda = 0.5
exp_beta = 1 / exp_lambda

exp_mean = 1 / exp_lambda
exp_median = math.log(2) / exp_lambda
exp_std = math.sqrt(1 / (exp_lambda ** 2))

exp_error = np.random.exponential(exp_beta, SELECTION_SIZE)

print("Expected mean:", exp_mean)
print("Expected median:", exp_median)
print("Expected std:", exp_std)
print("\n")
print("Real mean:", np.mean(exp_error))
print("Real median:", np.median(exp_error))
print("Real std:", np.std(exp_error))
print("\n")
print(exp_error[:25])
# Out:
# Expected mean: 2.0
# Expected median: 1.3862943611198906
# Expected std: 2.0
#
#
# Real mean: 2.096739980511
# Real median: 1.497158206184963
# Real std: 1.9944911403708618
#
#
# [5.41885407 6.02166174 1.95792071 1.85260973 3.19287285 3.7009592
#  5.01628843 1.71664928 0.83744331 1.95675681 7.00525826 0.61342861
#  1.76354919 0.73475994 0.28591337 6.88611042 5.54678156 2.09866502
#  1.32277067 1.6586213  5.85303281 0.57750105 3.28554712 1.77682149
#  1.12347646]

# %% [markdown]
# ### Exponential Error Plot

# %%
plt.hist(exp_error, bins=20, alpha=0.5, label="normal_error")
plt.show()

# %% [markdown]
# ## Creating models

# %% [markdown]
# ### Linear Model

# %%
linear_model = np.linspace(0, 100, SELECTION_SIZE, dtype=np.float32)
print(linear_model[:25])
# Out:
# [0.        0.1001001 0.2002002 0.3003003 0.4004004 0.5005005 0.6006006
#  0.7007007 0.8008008 0.9009009 1.001001  1.1011012 1.2012012 1.3013014
#  1.4014014 1.5015016 1.6016016 1.7017018 1.8018018 1.901902  2.002002
#  2.102102  2.2022023 2.3023024 2.4024024]

# %% [markdown]
# ### Linear Model Plot

# %%
plt.plot(np.arange(SELECTION_SIZE), linear_model)
plt.show()

# %% [markdown]
# ### Quadratic model

# %%
quadratic_model = np.square(np.linspace(0, 10, SELECTION_SIZE, dtype=np.float32))
print(quadratic_model[:25])
# Out:
# [0.         0.0001002  0.0004008  0.0009018  0.0016032  0.00250501
#  0.00360721 0.00490982 0.00641282 0.00811622 0.01002003 0.01212424
#  0.01442884 0.01693385 0.01963926 0.02254507 0.02565127 0.02895789
#  0.0324649  0.03617231 0.04008012 0.04418833 0.04849695 0.05300596
#  0.05771537]

# %% [markdown]
# ### Quadratic Model Plot

# %%
plt.plot(np.arange(SELECTION_SIZE), quadratic_model)
plt.show()

# %% [markdown]
# ## Combining model and error

# %% [markdown]
# ### Linear With Errors

# %%
linear_model_normal = linear_model + normal_error
linear_model_exp = linear_model + exp_error

plt.plot(np.arange(SELECTION_SIZE), linear_model, label="linear")
plt.plot(np.arange(SELECTION_SIZE), linear_model_normal, label="linear + normal")
plt.plot(np.arange(SELECTION_SIZE), linear_model_exp, label="linear + exp")
plt.legend()
plt.show()

# %%
plt.hist(linear_model, bins=50, alpha=0.5, label="linear")
plt.hist(linear_model_normal, bins=50, alpha=0.5, label="linear + normal")
plt.hist(linear_model_exp, bins=50, alpha=0.5, label="linear + exp")
plt.legend()
plt.show()

# %% [markdown]
# ### Quadratic With Errors

# %%
quadratic_model_normal = quadratic_model + normal_error
quadratic_model_exp = quadratic_model + exp_error

plt.plot(np.arange(SELECTION_SIZE), quadratic_model, label="quadratic")
plt.plot(np.arange(SELECTION_SIZE), quadratic_model_normal, label="quadratic + normal")
plt.plot(np.arange(SELECTION_SIZE), quadratic_model_exp, label="quadratic + exp")
plt.legend()
plt.show()

# %%
plt.hist(quadratic_model, bins=50, alpha=0.5, label="quadratic")
plt.hist(quadratic_model_normal, bins=50, alpha=0.5, label="quadratic + normal")
plt.hist(quadratic_model_exp, bins=50, alpha=0.5, label="quadratic + exp")
plt.legend()
plt.show()
